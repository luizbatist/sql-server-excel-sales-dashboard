# %%
pip install pyodbc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyodbc
import pandas as pd

dados_conexao = (
    "Driver={SQL Server};"
    "Server=HENRIQUE\MSSQLSERVER06;"
    "Database=AdventureWorksDW2014"
)

conexao = pyodbc.connect(dados_conexao)
print("Conexão bem sucedida")
# Out:
# Conexão bem sucedida

# %%
comando_sql = "SELECT * FROM dbo.VENDAS_INTERNET"

dados = pd.read_sql(comando_sql,conexao)
# Out:
# C:\Users\lhbpc\AppData\Local\Temp\ipykernel_2992\3580828522.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   dados = pd.read_sql(comando_sql,conexao)

# %%
display(dados)
# Out:
#       Nº PEDIDO DATA PEDIDO CATEGORIA PRODUTO    NOME CLIENTE SEXO  \
# 0       SO51247  2013-01-01             Bikes     Cindy Patel    F
# 1       SO51247  2013-01-01       Accessories     Cindy Patel    F
# 2       SO51247  2013-01-01       Accessories     Cindy Patel    F
# 3       SO51248  2013-01-01             Bikes        Brad She    M
# 4       SO51249  2013-01-01             Bikes    Nicole Brown    F
# ...         ...         ...               ...             ...  ...
# 52796   SO74250  2013-12-31          Clothing      Kyle Adams    M
# 52797   SO74251  2013-12-31       Accessories  Seth Hernandez    M
# 52798   SO74251  2013-12-31       Accessories  Seth Hernandez    M
# 52799   SO74251  2013-12-31       Accessories  Seth Hernandez    M
# 52800   SO74252  2013-12-31          Clothing      Kenneth Xu    M
#
#                  PAÍS  QTD. VENDIDA  CUSTO DA VENDA  RECEITA VENDA
# 0             Germany             1       1251.9813        2294.99
# ...

# %%
dados.shape
# Out:
# (52801, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52801 entries, 0 to 52800
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Nº PEDIDO          52801 non-null  object
#  1   DATA PEDIDO        52801 non-null  datetime64[ns]
#  2   CATEGORIA PRODUTO  52801 non-null  object
#  3   NOME CLIENTE       52801 non-null  object
#  4   SEXO               52801 non-null  object
#  5   PAÍS               52801 non-null  object
#  6   QTD. VENDIDA       52801 non-null  int64
#  7   CUSTO DA VENDA     52801 non-null  float64
#  8   RECEITA VENDA      52801 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(5)
# memory usage: 3.6+ MB

# %%
dados['DATA PEDIDO'] = pd.to_datetime(df['DATA PEDIDO'])

# %%
dados.dtypes
# Out:
# Nº PEDIDO                    object
# DATA PEDIDO          datetime64[ns]
# CATEGORIA PRODUTO            object
# NOME CLIENTE                 object
# SEXO                         object
# PAÍS                         object
# QTD. VENDIDA                  int64
# CUSTO DA VENDA              float64
# RECEITA VENDA               float64
# dtype: object

# %%
dados['RECEITA VENDA'].sum()
# Out:
# np.float64(16351550.339999994)

# %%
dados.groupby('PAÍS')['RECEITA VENDA'].sum().sort_values(ascending=False)
# Out:
# PAÍS
# United States     5462078.86
# Australia         4339443.38
# United Kingdom    2124007.29
# Germany           1761876.36
# France            1578511.80
# Canada            1085632.65
# Name: RECEITA VENDA, dtype: float64

# %%
dados.groupby('CATEGORIA PRODUTO')['RECEITA VENDA'].sum().sort_values(ascending=False)
# Out:
# CATEGORIA PRODUTO
# Bikes          15359502.36
# Accessories      668241.53
# Clothing         323806.45
# Name: RECEITA VENDA, dtype: float64

# %%
dados.groupby('CATEGORIA PRODUTO')['QTD. VENDIDA'].sum()
# Out:
# CATEGORIA PRODUTO
# Accessories    34409
# Bikes           9706
# Clothing        8686
# Name: QTD. VENDIDA, dtype: int64

# %%
ticket_medio_geral = (
    df.groupby('Nº PEDIDO')['RECEITA VENDA']
    .sum()
    .mean()
)
ticket_medio_geral
# Out:
# np.float64(768.0750782094038)

# %%
ticket_medio_pais = (
    dados.groupby(['PAÍS','Nº PEDIDO'])['RECEITA VENDA']
    .sum()
    .groupby('PAÍS')
    .mean()
    .sort_values(ascending=False)
)
ticket_medio_pais
# Out:
# PAÍS
# Australia         935.224866
# Germany           922.931566
# United Kingdom    893.566382
# France            823.428169
# United States     719.641484
# Canada            380.123477
# Name: RECEITA VENDA, dtype: float64

# %%
receita_total_pais = (
    dados.groupby('PAÍS')['RECEITA VENDA']
    .sum()
    .sort_values(ascending=False)
)
receita_total_pais
# Out:
# PAÍS
# United States     5462078.86
# Australia         4339443.38
# United Kingdom    2124007.29
# Germany           1761876.36
# France            1578511.80
# Canada            1085632.65
# Name: RECEITA VENDA, dtype: float64

# %%
ticket_medio_categoria = (
    dados.groupby(['CATEGORIA PRODUTO', 'Nº PEDIDO'])['RECEITA VENDA']
    .sum()
    .groupby('CATEGORIA PRODUTO')
    .mean()
    .sort_values(ascending=False)
)
ticket_medio_categoria
# Out:
# CATEGORIA PRODUTO
# Bikes          1582.475001
# Clothing         45.446519
# Accessories      38.453305
# Name: RECEITA VENDA, dtype: float64

# %%
ticket_bike_pais = (
    df[df['CATEGORIA PRODUTO'] == 'Bikes']
    .groupby(['PAÍS','Nº PEDIDO'])['RECEITA VENDA']
    .sum()
    .groupby('PAÍS')
    .mean()
    .sort_values(ascending = False)
)
ticket_bike_pais
# Out:
# PAÍS
# Australia         1623.419984
# Canada            1607.285548
# United Kingdom    1581.214417
# France            1580.217119
# United States     1559.050092
# Germany           1546.862173
# Name: RECEITA VENDA, dtype: float64
